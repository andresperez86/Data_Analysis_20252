# %% [markdown]
# observe a simple client for your predictive REST API

# %%
import requests
import json

url = 'http://0.0.0.0:7766/predict'

data = [[-1,0], [2,0]]
j_data = json.dumps(data)
headers = {'content-type': 'application/json', 'Accept-Charset': 'UTF-8'}
r = requests.post(url, data=j_data, headers=headers)
print(r, r.text)
# Out:
# <Response [200]> "[0 1]"

# %% [markdown]
# Proposed exercise
# create a REST API to serve the model you created for the TITANIC Kaggle competition
# create an example client call
